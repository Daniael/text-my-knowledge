# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniael/text-my-knowledge/blob/main/knowledge_test_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🎮 Level 1 — Variables
# Question:
#
#     Create a variable called age with the value 20.
#     - Print the variable.
#     - Print its data type.

# %%
age = 20
print(type(age))
# Out:
# <class 'int'>

# %% [markdown]
# 🎯 Level 2 — Variables (slightly different)
# Question:
#
#     Create a variable called temperature with the value 23.5.
#     - Print the variable.
#     - Print its data type.

# %%
temperature = 23.5
print(type(temperature))
# Out:
# <class 'float'>

# %% [markdown]
# 🎯 Level 3 — Strings (Beginner)
# Question:
#
#     Create a variable called name with the value "Danial".
#      - Print the first letter of the string.
#      - Print the last letter of the string.

# %%
name = "Danial"
print(name[0])
print(name[-1])
# Out:
# D
# l
